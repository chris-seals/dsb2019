# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('data/train.csv')
train_labels = pd.read_csv('data/train_labels.csv')
test = pd.read_csv('data/test.csv')
specs = pd.read_csv('data/specs.csv')
sample = pd.read_csv('data/sample_submission.csv')

# %% [markdown]
# Source: https://www.kaggle.com/robikscube/2019-data-science-bowl-an-introduction
# # train.csv / test.csv
# The data provided in these files are as follows:
# - `event_id` - Randomly generated unique identifier for the event type. Maps to event_id column in specs table.
# - `game_session` - Randomly generated unique identifier grouping events within a single game or video play session.
# - `timestamp` - Client-generated datetime
# - `event_data` - Semi-structured JSON formatted string containing the events parameters. Default fields are: event_count, event_code, and game_time; otherwise - fields are determined by the event type.
# - `installation_id` - Randomly generated unique identifier grouping game sessions within a single installed application instance.
# - `event_count` - Incremental counter of events within a game session (offset at 1). Extracted from event_data.
# - `event_code` - Identifier of the event 'class'. Unique per game, but may be duplicated across games. E.g. event code '2000' always identifies the 'Start Game' event for all games. Extracted from event_data.
# - `game_time` - Time in milliseconds since the start of the game session. Extracted from event_data.
# - `title` - Title of the game or video.
# - `type` - Media type of the game or video. Possible values are: 'Game', 'Assessment', 'Activity', 'Clip'.
# - `world` - The section of the application the game or video belongs to. Helpful to identify the educational curriculum goals of the media. Possible values are: 'NONE' (at the app's start screen), TREETOPCITY' (Length/Height), 'MAGMAPEAK' (Capacity/Displacement), 'CRYSTALCAVES' (Weight).

# %%
train.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count  event_code  game_time                          title  \
# 0            1        2000          0        Welcome to Lost Lagoon!
# 1            1        2000          0           Magma Peak - Level 1
# 2            1        2000          0  Sandcastle Builder (Activity)
# 3            2        3010         53  Sandcastle Builder (Activity)
# 4            3        3110       6972  Sandcastle Builder (Activity)
#
#        type      world
# 0      Clip       NONE
# 1      Clip  MAGMAPEAK
# 2  Activity  MAGMAPEAK
# 3  Activity  MAGMAPEAK
# 4  Activity  MAGMAPEAK

# %%
train.columns
# Out:
# Index(['event_id', 'game_session', 'timestamp', 'event_data',
#        'installation_id', 'event_count', 'event_code', 'game_time', 'title',
#        'type', 'world'],
#       dtype='object')

# %%
train.shape
# Out:
# (11341042, 11)

# %% [markdown]
# Source: https://www.kaggle.com/erikbruin/data-science-bowl-2019-eda-and-baseline
#
# So we have 11 million rows and just 11 columns. However, Kaggle provided the following note: Note that the training set contains many installation_ids which never took assessments, whereas every installation_id in the test set made an attempt on at least one assessment.
#
# As there is no point in keeping training data that cannot be used for training anyway, I am getting rid of the installation_ids that never took an assessment

# %%
# filtering by ids that took assessments
ids_w_assessments = train[train['type'] == 'Assessment']['installation_id'].drop_duplicates()
train = train[train['installation_id'].isin(ids_w_assessments)]

# %%
# convert timestamp to correct datetime type
train['timestamp'] = pd.to_datetime(train['timestamp'], infer_datetime_format=True)

# %%
train.shape
# Out:
# (8294138, 11)

# %%
orig_train = train.copy()

# %% [markdown]
# # brad test

# %%
train = orig_train.copy()

# %%
train.columns
# Out:
# Index(['event_id', 'game_session', 'timestamp', 'event_data',
#        'installation_id', 'event_count', 'event_code', 'game_time', 'title',
#        'type', 'world'],
#       dtype='object')

# %%
train.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count  event_code  game_time                          title  \
# 0            1        2000          0        Welcome to Lost Lagoon!
# 1            1        2000          0           Magma Peak - Level 1
# 2            1        2000          0  Sandcastle Builder (Activity)
# 3            2        3010         53  Sandcastle Builder (Activity)
# 4            3        3110       6972  Sandcastle Builder (Activity)
#
#        type      world
# 0      Clip       NONE
# 1      Clip  MAGMAPEAK
# 2  Activity  MAGMAPEAK
# 3  Activity  MAGMAPEAK
# 4  Activity  MAGMAPEAK

# %%
t1 = train[train['installation_id'] == '0006a69f']

# %%
t2 = t1[t1['title'] == 'Bird Measurer (Assessment)']

# %%
t2['world'].unique()
# Out:
# array(['TREETOPCITY'], dtype=object)

# %%
t3 = t2[t2['game_session'] == 'a9ef3ecb3d1acc6a']

# %%
t4 = t1[t1['game_session'] == 'a9ef3ecb3d1acc6a']

# %%
t3.shape
# Out:
# (32, 11)

# %%
t4.shape
# Out:
# (32, 11)

# %%
t5 = t1[t1['world'] == 'TREETOPCITY']

# %%
t1['world'].nunique()
# Out:
# 3

# %%
t5.groupby(['game_session'])

# %%
condensed = pd.DataFrame(columns=t5.columns)

for key, group in t5.groupby(['game_session']):
    temp = pd.DataFrame(index=range(1,2), columns=t5.columns)
    
    unique_cols = ['event_id', 'game_session', 'installation_id', 'title', 'type', 'world']
    for col in unique_cols:
        temp[col] = group[col].unique()[0]
        
    last_val_cols = ['timestamp', 'event_count', 'game_time']
    for col in last_val_cols:
        temp[col] = group[col].iloc[-1]
    
    condensed = condensed.append(temp, ignore_index=True)

# %%
condensed.sort_values(by='timestamp', inplace=True)
condensed.reset_index(drop=True, inplace=True)

# %%
condensed['assessment_group'] = np.nan
list_assessement_groups = np.arange(len(condensed.loc[condensed['type'] == 'Assessment', 'assessment_group']))
condensed.loc[condensed['type'] == 'Assessment', 'assessment_group'] = list_assessement_groups

# %%
condensed['assessment_group'].fillna(method='backfill', inplace=True)

# %% [markdown]
# note: one of the values didn't merge

# %%
condensed[condensed['type'] == 'Assessment'].shape
# Out:
# (6, 12)

# %%
condensed.merge(train_labels, on=['game_session', 'installation_id', 'title']).shape
# Out:
# (5, 16)

# %%
cm = condensed.merge(train_labels, on=['game_session', 'installation_id', 'title'], how='left')

# %%
types = train['type'].unique() + '_counts'
totals = ['total_game_time', 'total_event_count']
flattened = pd.DataFrame(columns=list(cm.columns) + list(types) + totals)

for key, group in cm.groupby(['assessment_group']):
    temp = pd.DataFrame(index=range(1,2), columns=list(cm.columns) + list(types) + totals)
    #temp = group
    temp_counts = group['type'].value_counts()
    
    for col in group.columns:
        temp[col] = group[col].iloc[-1]
    
    for key, value in temp_counts.items():
        temp[key + '_counts'] = value
        
    temp['total_game_time'] = sum(group['game_time'])
    temp['total_event_count'] = sum(group['event_count'])
        
    flattened = flattened.append(temp, ignore_index=True)

# %% [markdown]
# ### TODO: figure out what to do the with nan values in the counts and accuracy group columns

# %%
flattened
# Out:
#    event_id      game_session                         timestamp  event_data  \
# 0  3bfd1a65  901acc108f55a5a1  2019-08-06 05:22:41.147000+00:00         NaN
# 1  f56e0afc  77b8ee947eb84b4e  2019-08-06 05:36:51.915000+00:00         NaN
# 2  3bfd1a65  6bdf9623adc94d89  2019-08-06 05:38:16.835000+00:00         NaN
# 3  3bfd1a65  e7e7db2a241eadcc  2019-08-06 20:34:44.115000+00:00         NaN
# 4  3bfd1a65  9501794defd84e4d  2019-08-06 20:35:25.648000+00:00         NaN
# 5  f56e0afc  a9ef3ecb3d1acc6a  2019-08-06 20:50:35.426000+00:00         NaN
#
#   installation_id event_count  event_code game_time  \
# 0        0006a69f          48         NaN     39803
# 1        0006a69f          87         NaN     92799
# 2        0006a69f          35         NaN     26827
# 3        0006a69f          17         NaN      8789
# 4        0006a69f          42         NaN     31843
# 5        0006a69f          32         NaN     36368
#
#                           title        type        world  assessment_group  \
# 0  Mushroom Sorter (Assessment)  Assessment  TREETOPCITY               0.0
# 1    Bird Measurer (Assessment)  Assessment  TREETOPCITY               1.0
# 2  Mushroom Sorter (Assessment)  Assessment  TREETOPCITY               2.0
# 3  Mushroom Sorter (Assessment)  Assessment  TREETOPCITY               3.0
# 4  Mushroom Sorter (Assessment)  Assessment  TREETOPCITY               4.0
# 5    Bird Measurer (Assessment)  Assessment  TREETOPCITY               5.0
#
#    num_correct  num_incorrect  accuracy  accuracy_group Clip_counts  \
# 0          1.0            0.0       1.0             3.0           7
# 1          0.0           11.0       0.0             0.0           3
# 2          1.0            0.0       1.0             3.0         NaN
# 3          NaN            NaN       NaN             NaN           6
# 4          1.0            1.0       0.5             2.0         NaN
# 5          1.0            0.0       1.0             3.0           4
#
#   Activity_counts Game_counts Assessment_counts total_game_time  \
# 0               2           3                 1          460761
# 1               1           2                 1          469592
# 2             NaN         NaN                 1           26827
# 3               2           1                 1         1685943
# 4             NaN         NaN                 1           31843
# 5               1           3                 1          493389
#
#   total_event_count
# 0               458
# 1               535
# 2                35
# 3               400
# 4                42
# 5               417

# %% [markdown]
# Try some ML!

# %%
data = flattened.copy()

# %%
data.drop(['event_id', 'game_session', 'timestamp', 'event_data', 'installation_id', 'event_code', 'type',
           'assessment_group'], axis=1, inplace=True)

# %%
data
# Out:
#   event_count game_time                         title        world  \
# 0          48     39803  Mushroom Sorter (Assessment)  TREETOPCITY
# 1          87     92799    Bird Measurer (Assessment)  TREETOPCITY
# 2          35     26827  Mushroom Sorter (Assessment)  TREETOPCITY
# 3          17      8789  Mushroom Sorter (Assessment)  TREETOPCITY
# 4          42     31843  Mushroom Sorter (Assessment)  TREETOPCITY
# 5          32     36368    Bird Measurer (Assessment)  TREETOPCITY
#
#    num_correct  num_incorrect  accuracy  accuracy_group Clip_counts  \
# 0          1.0            0.0       1.0             3.0           7
# 3567  9b01374f  b443af838d18495a 2019-08-06 20:31:23.229000+00:00
# 3679  27253bdc  09fd0cc02e6ee5f4 2019-08-06 20:33:04.894000+00:00
# 3680  3bfd1a65  e7e7db2a241eadcc 2019-08-06 20:34:35.357000+00:00
# 3697  3bfd1a65  9501794defd84e4d 2019-08-06 20:34:53.812000+00:00
# 3739  15ba1109  8043825259dc7ddd 2019-08-06 20:35:37.098000+00:00
# 3854  27253bdc  73e3175bfa86fa3c 2019-08-06 20:38:14.132000+00:00
# 3855  27253bdc  625e99c32c43e0e1 2019-08-06 20:38:23.940000+00:00
# 3856  27253bdc  bbda08fee616189a 2019-08-06 20:41:07.522000+00:00
# 3857  48349b14  7c13746843dfea07 2019-08-06 20:41:44.219000+00:00
# 3858  48349b14  744663d06c3d0b65 2019-08-06 20:41:59.812000+00:00
# 4008  27253bdc  a083d98139c9afe3 2019-08-06 20:46:12.295000+00:00
# 4009  c7f7f0e1  9688b7024d725ab4 2019-08-06 20:48:27.173000+00:00
# 4124  f56e0afc  a9ef3ecb3d1acc6a 2019-08-06 20:49:59.095000+00:00
#
#                                              event_data installation_id  \
# 1775             {"event_code": 2000, "event_count": 1}        0006a69f
# 1776             {"event_code": 2000, "event_count": 1}        0006a69f
# 1777  {"version":"1.0","round":0,"event_count":1,"ga...        0006a69f
# 1805  {"version":"1.0","round":0,"event_count":1,"ga...        0006a69f
# 1840  {"version":"1.0","round":0,"event_count":1,"ga...        0006a69f
# 1930             {"event_code": 2000, "event_count": 1}        0006a69f
# 1931             {"event_code": 2000, "event_count": 1}        0006a69f
# 1932  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 2016             {"event_code": 2000, "event_count": 1}        0006a69f
# 2017             {"event_code": 2000, "event_count": 1}        0006a69f
# 2018  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 2184             {"event_code": 2000, "event_count": 1}        0006a69f
# 2185  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 2233  {"version":"1","round":0,"event_count":1,"game...        0006a69f
# 2413             {"event_code": 2000, "event_count": 1}        0006a69f
# 2414             {"event_code": 2000, "event_count": 1}        0006a69f
# 2415  {"version":"1.0","round":0,"event_count":1,"ga...        0006a69f
# 2476             {"event_code": 2000, "event_count": 1}        0006a69f
# 2477  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 2681  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 2768  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 3297             {"event_code": 2000, "event_count": 1}        0006a69f
# 3298             {"event_code": 2000, "event_count": 1}        0006a69f
# 3299  {"version":"1.0","round":0,"event_count":1,"ga...        0006a69f
# 3349             {"event_code": 2000, "event_count": 1}        0006a69f
# 3350  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 3565             {"event_code": 2000, "event_count": 1}        0006a69f
# 3566             {"event_code": 2000, "event_count": 1}        0006a69f
# 3567  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 3679             {"event_code": 2000, "event_count": 1}        0006a69f
# 3680  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 3697  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 3739  {"version":"1","round":0,"event_count":1,"game...        0006a69f
# 3854             {"event_code": 2000, "event_count": 1}        0006a69f
# 3855             {"event_code": 2000, "event_count": 1}        0006a69f
# 3856             {"event_code": 2000, "event_count": 1}        0006a69f
# 3857  {"version":"1.0","round":0,"event_count":1,"ga...        0006a69f
# 3858  {"version":"1.0","round":0,"event_count":1,"ga...        0006a69f
# 4008             {"event_code": 2000, "event_count": 1}        0006a69f
# 4009  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
#
# 3854        Clip  TREETOPCITY
# 3855        Clip  TREETOPCITY
# 3856        Clip  TREETOPCITY
# 3857        Game  TREETOPCITY
# 3858        Game  TREETOPCITY
# 4008        Clip  TREETOPCITY
# 4009    Activity  TREETOPCITY
# 4124  Assessment  TREETOPCITY

# %% [markdown]
# ## Train Labels
#
# You can get a unique set of training labels by combining `game_session` and `installation_id`.
#
# Labels are only on assessments.

# %%
train_labels.shape
# Out:
# (17690, 7)

# %%
# Do I need to create a mapping? I don't think so since the merge worked

tls = list(map(lambda x, y: str(x) + '_' + str(y), train_labels['game_session'], train_labels['installation_id']))
len(set(tls))
# Out:
# 17690

# %%
specs = pd.read_csv('data/specs.csv')

# %%
specs
# Out:
#      event_id                                               info  \
# 0    2b9272f4  The end of system-initiated feedback (Correct)...
# 1    df4fe8b6  The end of system-initiated feedback (Incorrec...
# 2    3babcb9b  The end of system-initiated instruction event ...
# 3    7f0836bf  The end of system-initiated instruction event ...
# 4    ab3136ba  The end of system-initiated instruction event ...
# ..        ...                                                ...
# 381  29f54413  The start round event is triggered at the star...
# 382  06372577  The start tutorial event is triggered at the s...
# 383  2a444e03  This event occurs when the player picks up a w...
# 384  9e6b7fb5  This event occurs when the player clicks on th...
# 385  d3640339  This event occurs when the player clicks on th...
#
#                                                   args
# 0    [{"name":"game_time","type":"int","info":"mill...
# 1    [{"name":"game_time","type":"int","info":"mill...
# 2    [{"name":"game_time","type":"int","info":"mill...
# 3    [{"name":"game_time","type":"int","info":"mill...
# 4    [{"name":"game_time","type":"int","info":"mill...
# ..                                                 ...
# 381  [{"name":"game_time","type":"int","info":"mill...
# 382  [{"name":"game_time","type":"int","info":"mill...
# 383  [{"name":"game_time","type":"int","info":"mill...
# 384  [{"name":"game_time","type":"int","info":"mill...
# 385  [{"name":"game_time","type":"int","info":"mill...
#
# [386 rows x 3 columns]

# %%
# https://www.kaggle.com/manyregression/fastai-2019-data-science-bowl
# do we need this?
'''
specs['hashed_info']=specs['info'].transform(hash)
unique_specs=pd.DataFrame(specs[['hashed_info']].drop_duplicates())
unique_specs["id"] = np.arange(len(unique_specs))
specs = pd.merge(specs,unique_specs,on='hashed_info',how='left')
event_id_mapping = dict(zip(specs.event_id,specs.id))
train["event_id"] = train["event_id"].map(event_id_mapping)'''
#raw_test["event_id"] = raw_test["event_id"].map(event_id_mapping)

# %% [markdown]
# # end brad test

# %%
from typing import Any
import re

def add_datepart(df: pd.DataFrame, field_name: str,
                 prefix: str = None, drop: bool = True, time: bool = True, date: bool = True):
    """
    Helper function that adds columns relevant to a date in the column `field_name` of `df`.
    from fastai: https://github.com/fastai/fastai/blob/master/fastai/tabular/transform.py#L55
    """
    field = df[field_name]
    prefix = ifnone(prefix, re.sub('[Dd]ate$', '', field_name))
    attr = ['Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Is_month_end', 'Is_month_start']
    if date:
        attr.append('Date')
    if time:
        attr = attr + ['Hour', 'Minute']
    for n in attr:
        df[prefix + n] = getattr(field.dt, n.lower())
    if drop:
        df.drop(field_name, axis=1, inplace=True)
    return df

def ifnone(a: Any, b: Any) -> Any:
    """`a` if `a` is not None, otherwise `b`.
    from fastai: https://github.com/fastai/fastai/blob/master/fastai/core.py#L92"""
    return b if a is None else a

# %% [markdown]
# # test area for looking at events by day

# %%
train = orig_train.copy()

# %%
train['timestamp'] = pd.to_datetime(train['timestamp'], infer_datetime_format=True)

# %%
train = add_datepart(train, "timestamp", prefix="timestamp_", time=True)

# %%
train.columns
# Out:
# Index(['event_id', 'game_session', 'event_data', 'installation_id',
#        'event_count', 'event_code', 'game_time', 'title', 'type', 'world',
#        'timestamp_Year', 'timestamp_Month', 'timestamp_Week', 'timestamp_Day',
#        'timestamp_Dayofweek', 'timestamp_Is_month_end',
#        'timestamp_Is_month_start', 'timestamp_Date', 'timestamp_Hour',
#        'timestamp_Minute'],
#       dtype='object')

# %%
train.head()
# Out:
#       event_id      game_session  \
# 1538  27253bdc  34ba1a28d02ba8ba
# 1539  27253bdc  4b57c9a59474a1b9
# 1540  77261ab5  2b9d5af79bcdb79f
# 1541  b2dba42b  2b9d5af79bcdb79f
# 1542  1325467d  2b9d5af79bcdb79f
#
#                                              event_data installation_id  \
# 1538             {"event_code": 2000, "event_count": 1}        0006a69f
# 1539             {"event_code": 2000, "event_count": 1}        0006a69f
# 1540  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 1541  {"description":"Let's build a sandcastle! Firs...        0006a69f
# 1542  {"coordinates":{"x":273,"y":650,"stage_width":...        0006a69f
#
#       event_count  event_code  game_time                          title  \
# 1538            1        2000          0        Welcome to Lost Lagoon!
# 1539            1        2000          0           Magma Peak - Level 1
# 1540            1        2000          0  Sandcastle Builder (Activity)
# 1541            2        3010         29  Sandcastle Builder (Activity)
# 1542            3        4070       2137  Sandcastle Builder (Activity)
#
#           type      world  timestamp_Year  timestamp_Month  timestamp_Week  \
# 1538      Clip       NONE            2019                8              32
# 1539      Clip  MAGMAPEAK            2019                8              32
# 1540  Activity  MAGMAPEAK            2019                8              32
# 1541  Activity  MAGMAPEAK            2019                8              32
# 1542  Activity  MAGMAPEAK            2019                8              32
#
#       timestamp_Day  timestamp_Dayofweek  timestamp_Is_month_end  \
# 1538              6                    1                   False
# 1539              6                    1                   False
# 1540              6                    1                   False
# 1541              6                    1                   False
# 1542              6                    1                   False
#
#       timestamp_Is_month_start timestamp_Date  timestamp_Hour  \
# 1538                     False     2019-08-06               4
# 1539                     False     2019-08-06               4
# 1540                     False     2019-08-06               4
# 1541                     False     2019-08-06               4
# 1542                     False     2019-08-06               4
#
#       timestamp_Minute
# 1538                57
# 1539                57
# 1540                58
# 1541                58
# 1542                58

# %%
train[train['type'] == 'Assessment'].head()
# Out:
#       event_id      game_session  \
# 2185  3bfd1a65  901acc108f55a5a1
# 2186  db02c830  901acc108f55a5a1
# 2187  a1e4395d  901acc108f55a5a1
# 2188  a52b92d5  901acc108f55a5a1
# 2189  a1e4395d  901acc108f55a5a1
#
#                                              event_data installation_id  \
# 2185  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 2186  {"event_count":2,"game_time":37,"event_code":2...        0006a69f
# 2187  {"description":"Pull three mushrooms out of th...        0006a69f
# 2188  {"description":"Pull three mushrooms out of th...        0006a69f
# 2189  {"description":"To pick a mushroom, pull it ou...        0006a69f
#
#       event_count  event_code  game_time                         title  \
# 2185            1        2000          0  Mushroom Sorter (Assessment)
# 2186            2        2025         37  Mushroom Sorter (Assessment)
# 2187            3        3010         37  Mushroom Sorter (Assessment)
# 2188            4        3110       3901  Mushroom Sorter (Assessment)
# 2189            5        3010       3901  Mushroom Sorter (Assessment)
#
#             type        world  timestamp_Year  timestamp_Month  \
# 2185  Assessment  TREETOPCITY            2019                8
# 2186  Assessment  TREETOPCITY            2019                8
# 2187  Assessment  TREETOPCITY            2019                8
# 2188  Assessment  TREETOPCITY            2019                8
# 2189  Assessment  TREETOPCITY            2019                8
#
#       timestamp_Week  timestamp_Day  timestamp_Dayofweek  \
# 2185              32              6                    1
# 2186              32              6                    1
# 2187              32              6                    1
# 2188              32              6                    1
# 2189              32              6                    1
#
#       timestamp_Is_month_end  timestamp_Is_month_start timestamp_Date  \
# 2185                   False                     False     2019-08-06
# 2186                   False                     False     2019-08-06
# 2187                   False                     False     2019-08-06
# 2188                   False                     False     2019-08-06
# 2189                   False                     False     2019-08-06
#
#       timestamp_Hour  timestamp_Minute
# 2185               5                22
# 2186               5                22
# 2187               5                22
# 2188               5                22
# 2189               5                22

# %%
#t1 = train[train['event_id'] == '3bfd1a65']
#t1 = t1[t1['installation_id'] == '0006a69f']
t1 = train[train['installation_id'] == '0006a69f']

# %%
t1.shape
# Out:
# (3801, 20)

# %%
t1
# Out:
#       event_id      game_session  \
# 1538  27253bdc  34ba1a28d02ba8ba
# 1539  27253bdc  4b57c9a59474a1b9
# 1540  77261ab5  2b9d5af79bcdb79f
# 1541  b2dba42b  2b9d5af79bcdb79f
# 1542  1325467d  2b9d5af79bcdb79f
# ...        ...               ...
# 5334  832735e1  0721802df0531701
# 5335  ab3136ba  0721802df0531701
# 5336  832735e1  0721802df0531701
# 5337  ab3136ba  0721802df0531701
# 5338  76babcde  0721802df0531701
#
#                                              event_data installation_id  \
# 1538             {"event_code": 2000, "event_count": 1}        0006a69f
# 1539             {"event_code": 2000, "event_count": 1}        0006a69f
# 1540  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 1541  {"description":"Let's build a sandcastle! Firs...        0006a69f
# 1542  {"coordinates":{"x":273,"y":650,"stage_width":...        0006a69f
# ...                                                 ...             ...
# 5334  {"description":"Let's warm up. Tap a dinosaur ...        0006a69f
# 5335  {"description":"Let's warm up. Tap a dinosaur ...        0006a69f
# 5336  {"description":"Let's warm up. Tap a dinosaur ...        0006a69f
# 5337  {"description":"Let's warm up. Tap a dinosaur ...        0006a69f
# 5338  {"coordinates":{"x":1013,"y":195,"stage_width"...        0006a69f
#
#       event_count  event_code  game_time                          title  \
# 1538            1        2000          0        Welcome to Lost Lagoon!
# 1539            1        2000          0           Magma Peak - Level 1
# 1540            1        2000          0  Sandcastle Builder (Activity)
# 1541            2        3010         29  Sandcastle Builder (Activity)
# 1542            3        4070       2137  Sandcastle Builder (Activity)
# ...           ...         ...        ...                            ...
# 5334           11        3010      23145                      Dino Dive
# 5335           12        3110      26804                      Dino Dive
# 5336           13        3010      41805                      Dino Dive
# 5337           14        3110      45405                      Dino Dive
# 5338           15        4070     167337                      Dino Dive
#
#           type      world  timestamp_Year  timestamp_Month  timestamp_Week  \
# 1538      Clip       NONE            2019                8              32
# 1539      Clip  MAGMAPEAK            2019                8              32
# 1540  Activity  MAGMAPEAK            2019                8              32
# 1541  Activity  MAGMAPEAK            2019                8              32
# 1542  Activity  MAGMAPEAK            2019                8              32
# ...        ...        ...             ...              ...             ...
# 5334      Game  MAGMAPEAK            2019                8              35
# 5335      Game  MAGMAPEAK            2019                8              35
# 5336      Game  MAGMAPEAK            2019                8              35
# 5337      Game  MAGMAPEAK            2019                8              35
# 5338      Game  MAGMAPEAK            2019                8              35
#
#       timestamp_Day  timestamp_Dayofweek  timestamp_Is_month_end  \
# 1538              6                    1                   False
# 1539              6                    1                   False
# 1540              6                    1                   False
# 1541              6                    1                   False
# 1542              6                    1                   False
# ...             ...                  ...                     ...
# 5334             29                    3                   False
# 5335             29                    3                   False
# 5336             29                    3                   False
# 5337             29                    3                   False
# 5338             29                    3                   False
#
#       timestamp_Is_month_start timestamp_Date  timestamp_Hour  \
# 1538                     False     2019-08-06               4
# 1539                     False     2019-08-06               4
# 1540                     False     2019-08-06               4
# 1541                     False     2019-08-06               4
# 1542                     False     2019-08-06               4
# ...                        ...            ...             ...
# 5334                     False     2019-08-29              16
# 5335                     False     2019-08-29              16
# 5336                     False     2019-08-29              16
# 5337                     False     2019-08-29              16
# 5338                     False     2019-08-29              16
#
#       timestamp_Minute
# 1538                57
# 1539                57
# 1540                58
# 1541                58
# 1542                58
# ...                ...
# 5334                33
# 5335                33
# 5336                34
# 5337                34
# 5338                39
#
# [3801 rows x 20 columns]

# %%
for key, group in t1.groupby(['timestamp_Month', 'timestamp_Day', 'timestamp_Year']):
#for key, group in t1.groupby(['title']):
    print(key)
    print(group.shape)
# Out:
# (8, 6, 2019)
# (2719, 20)
# (8, 9, 2019)
# (442, 20)
# (8, 29, 2019)
# (640, 20)

# %%
key
# Out:
# (8, 29, 2019)

# %%
t2 = group.copy()

# %%
t2
# Out:
#       event_id      game_session  \
# 4699  77261ab5  d37c0b021d22c3ac
# 4700  b2dba42b  d37c0b021d22c3ac
# 4701  1325467d  d37c0b021d22c3ac
# 4702  1325467d  d37c0b021d22c3ac
# 4703  1325467d  d37c0b021d22c3ac
# ...        ...               ...
# 5334  832735e1  0721802df0531701
# 5335  ab3136ba  0721802df0531701
# 5336  832735e1  0721802df0531701
# 5337  ab3136ba  0721802df0531701
# 5338  76babcde  0721802df0531701
#
#                                              event_data installation_id  \
# 4699  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 4700  {"description":"Let's build a sandcastle! Firs...        0006a69f
# 4701  {"coordinates":{"x":244,"y":581,"stage_width":...        0006a69f
# 4702  {"coordinates":{"x":843,"y":241,"stage_width":...        0006a69f
# 4703  {"coordinates":{"x":806,"y":616,"stage_width":...        0006a69f
# ...                                                 ...             ...
# 5334  {"description":"Let's warm up. Tap a dinosaur ...        0006a69f
# 5335  {"description":"Let's warm up. Tap a dinosaur ...        0006a69f
# 5336  {"description":"Let's warm up. Tap a dinosaur ...        0006a69f
# 5337  {"description":"Let's warm up. Tap a dinosaur ...        0006a69f
# 5338  {"coordinates":{"x":1013,"y":195,"stage_width"...        0006a69f
#
#       event_count  event_code  game_time                          title  \
# 4699            1        2000          0  Sandcastle Builder (Activity)
# 4700            2        3010         34  Sandcastle Builder (Activity)
# 4701            3        4070       2298  Sandcastle Builder (Activity)
# 4702            4        4070       3482  Sandcastle Builder (Activity)
# 4703            5        4070       4115  Sandcastle Builder (Activity)
# ...           ...         ...        ...                            ...
# 5334           11        3010      23145                      Dino Dive
# 5335           12        3110      26804                      Dino Dive
# 5336           13        3010      41805                      Dino Dive
# 5337           14        3110      45405                      Dino Dive
# 5338           15        4070     167337                      Dino Dive
#
#           type      world  timestamp_Year  timestamp_Month  timestamp_Week  \
# 4699  Activity  MAGMAPEAK            2019                8              35
# 4700  Activity  MAGMAPEAK            2019                8              35
# 4701  Activity  MAGMAPEAK            2019                8              35
# 4702  Activity  MAGMAPEAK            2019                8              35
# 4703  Activity  MAGMAPEAK            2019                8              35
# ...        ...        ...             ...              ...             ...
# 5334      Game  MAGMAPEAK            2019                8              35
# 5335      Game  MAGMAPEAK            2019                8              35
# 5336      Game  MAGMAPEAK            2019                8              35
# 5337      Game  MAGMAPEAK            2019                8              35
# 5338      Game  MAGMAPEAK            2019                8              35
#
#       timestamp_Day  timestamp_Dayofweek  timestamp_Is_month_end  \
# 4699             29                    3                   False
# 4700             29                    3                   False
# 4701             29                    3                   False
# 4702             29                    3                   False
# 4703             29                    3                   False
# ...             ...                  ...                     ...
# 5334             29                    3                   False
# 5335             29                    3                   False
# 5336             29                    3                   False
# 5337             29                    3                   False
# 5338             29                    3                   False
#
#       timestamp_Is_month_start timestamp_Date  timestamp_Hour  \
# 4699                     False     2019-08-29              16
# 4700                     False     2019-08-29              16
# 4701                     False     2019-08-29              16
# 4702                     False     2019-08-29              16
# 4703                     False     2019-08-29              16
# ...                        ...            ...             ...
# 5334                     False     2019-08-29              16
# 5335                     False     2019-08-29              16
# 5336                     False     2019-08-29              16
# 5337                     False     2019-08-29              16
# 5338                     False     2019-08-29              16
#
#       timestamp_Minute
# 4699                14
# 4700                14
# 4701                14
# 4702                14
# 4703                14
# ...                ...
# 5334                33
# 5335                33
# 5336                34
# 5337                34
# 5338                39
#
# [640 rows x 20 columns]

# %%
t2[t2['type'] == 'Assessment']
# Out:
# Empty DataFrame
# Columns: [event_id, game_session, event_data, installation_id, event_count, event_code, game_time, title, type, world, timestamp_Year, timestamp_Month, timestamp_Week, timestamp_Day, timestamp_Dayofweek, timestamp_Is_month_end, timestamp_Is_month_start, timestamp_Date, timestamp_Hour, timestamp_Minute]
# Index: []

# %%
t2.loc[5080, 'event_data']
# Out:
# '{"description":"To play again, tap here!","identifier":"Mom_ToPlayAgainTouch","media_type":"audio","total_duration":1913,"round":2,"event_count":122,"game_time":144671,"event_code":3010}'

# %% [markdown]
# # end test area

# %%
# https://www.kaggle.com/robikscube/2019-data-science-bowl-an-introduction

train['cleared'] = True
train.loc[train['event_data'].str.contains('false') & train['event_code'].isin([4100, 4110]), 'cleared'] = False

test['cleared'] = True
test.loc[test['event_data'].str.contains('false') & test['event_code'].isin([4100, 4110]), 'cleared'] = False

# %% [markdown]
# Some paraphrased notes from: https://www.kaggle.com/manyregression/fastai-2019-data-science-bowl
#
# The intent of the competition is to use the gameplay data to forecast how many attempts a child will take to pass a given assessment.
#
# For each installation_id represented in the test set, you must predict the accuracy_group **of the last assessment** for that installation_id
#
# * Assessment attempts are captured in event_code 4100 for all assessments except for Bird Measurer, which uses event_code 4110.
# * Each application install is represented by an installation_id. This will typically correspond to one child, but you should expect noise from issues such as shared devices.
# * In the training set, you are provided **the full history of gameplay data.**
# * In the test set, **we have truncated the history after the start event of a single assessment, chosen randomly, for which you must predict the number of attempts.**

# %%
specs['hashed_info'] = specs['info'].transform(hash)
unique_specs = specs[['hashed_info']].drop_duplicates()
unique_specs["id"] = np.arange(len(unique_specs))
specs = pd.merge(specs,unique_specs, on='hashed_info', how='left')
event_id_mapping = dict(zip(specs.event_id, specs.id))

# %%
def get_accuracy(correct_data):
    # Rounding correct > 1 to 1 lowers the score. Why?
    correct = len(correct_data.loc[correct_data])
    wrong = len(correct_data.loc[~correct_data])
    accuracy = correct/(correct + wrong) if correct + wrong else 0
    return accuracy, correct, wrong

def get_group(accuracy):
    if not accuracy:
        return 0
    elif accuracy == 1:
        return 3
    elif accuracy >= 0.5:
        return 2
    return 1

# %% [markdown]
# # begin lyons test

# %%
train = orig_train.copy()

# %%
### encode title lyons v2

train['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), train['title'], train['event_code']))
test['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), test['title'], test['event_code']))
all_title_event_code = list(set(train["title_event_code"].unique()).union(test["title_event_code"].unique()))
# make a list with all the unique 'titles' from the train and test set
list_of_user_activities = list(set(train['title'].unique()).union(set(test['title'].unique())))
# make a list with all the unique 'event_code' from the train and test set
list_of_event_code = list(set(train['event_code'].unique()).union(set(test['event_code'].unique())))
list_of_event_id = list(set(train['event_id'].unique()).union(set(test['event_id'].unique())))
# make a list with all the unique worlds from the train and test set
list_of_worlds = list(set(train['world'].unique()).union(set(test['world'].unique())))
# create a dictionary numerating the titles
activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))
activities_labels = dict(zip(np.arange(len(list_of_user_activities)), list_of_user_activities))
activities_world = dict(zip(list_of_worlds, np.arange(len(list_of_worlds))))
assess_titles = list(set(train[train['type'] == 'Assessment']['title'].value_counts().index).union(set(test[test['type'] == 'Assessment']['title'].value_counts().index)))
# replace the text titles with the number titles from the dict
train['title'] = train['title'].map(activities_map)
test['title'] = test['title'].map(activities_map)
train['world'] = train['world'].map(activities_world)
test['world'] = test['world'].map(activities_world)
train_labels['title'] = train_labels['title'].map(activities_map)
win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
# then, it set one element, the 'Bird Measurer (Assessment)' as 4110, 10 more than the rest
win_code[activities_map['Bird Measurer (Assessment)']] = 4110
# convert text into datetime
train['timestamp'] = pd.to_datetime(train['timestamp'])
test['timestamp'] = pd.to_datetime(test['timestamp'])

# %%
def truncate_training(train):
    
    compiled_data = []
    
    # Loop through installation ids
    for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort=False)), total=train.installation_id.nunique(), desc='Installation_id', position=0):
        
        user_df = user_sample.reset_index(drop=True)
        
        # Get an array of the sessions with assessments
        assessment_sessions = user_df[user_df['type'] == 'Assessment']['game_session'].unique()
        
        # Pick a random session
        assessment_to_truncate = random.choice(assessment_sessions)
        
        # Grab the row location for that session's event code 2000
        assessment_to_truncate_start_index = user_df.index[(user_df['game_session'] == assessment_to_truncate) & 
                                                    (user_df['event_code'] == 2000)][0]
        
        # Now get a slice of the user_sample from the beginning to the truncated assessment start
        truncated_user_sample = user_df.iloc[:assessment_to_truncate_start_index + 1]
        
        compiled_data.append(truncated_user_sample)
        
    return pd.concat(compiled_data)

# %%
# truncate train to match test
# train_truncated = truncate_training(train)

# %%
train
# Out:
#           event_id      game_session                        timestamp  \
# 1538      27253bdc  34ba1a28d02ba8ba 2019-08-06 04:57:18.904000+00:00
# 1539      27253bdc  4b57c9a59474a1b9 2019-08-06 04:57:45.301000+00:00
# 1540      77261ab5  2b9d5af79bcdb79f 2019-08-06 04:58:14.538000+00:00
# 1541      b2dba42b  2b9d5af79bcdb79f 2019-08-06 04:58:14.615000+00:00
# 1542      1325467d  2b9d5af79bcdb79f 2019-08-06 04:58:16.680000+00:00
# ...            ...               ...                              ...
# 11337821  28520915  5448d652309a6324 2019-09-22 02:07:27.562000+00:00
# 11337822  91561152  5448d652309a6324 2019-09-22 02:07:27.562000+00:00
# 11337823  d3268efa  5448d652309a6324 2019-09-22 02:07:27.566000+00:00
# 11337824  b5053438  5448d652309a6324 2019-09-22 02:07:28.311000+00:00
# 11337825  2b058fe3  5448d652309a6324 2019-09-22 02:07:31.963000+00:00
#
#                                                  event_data installation_id  \
# 1538                 {"event_code": 2000, "event_count": 1}        0006a69f
# 1539                 {"event_code": 2000, "event_count": 1}        0006a69f
# 1540      {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 1541      {"description":"Let's build a sandcastle! Firs...        0006a69f
# 1542      {"coordinates":{"x":273,"y":650,"stage_width":...        0006a69f
# ...                                                     ...             ...
# 11337821  {"misses":1,"prompt":"holds least","mode":"sel...        ffeb0b1b
# 11337822  {"bucket":1,"buckets_placed":[3,1,2],"target_b...        ffeb0b1b
# 11337823  {"description":"Awesome.","identifier":"Dot_Aw...        ffeb0b1b
# 11337824  {"description":"Awesome.","identifier":"Dot_Aw...        ffeb0b1b
# 11337825  {"session_duration":71511,"event_count":61,"ga...        ffeb0b1b
#
#           event_count  event_code  game_time  title        type  world  \
# 1538                1        2000          0     72        Clip      5
# 1539                1        2000          0     78        Clip      6
# 1540                1        2000          0      9    Activity      6
# 1541                2        3010         29      9    Activity      6
# 1542                3        4070       2137      9    Activity      6
# ...               ...         ...        ...    ...         ...    ...
# 11337821           58        2030      67094     64  Assessment      6
# 11337822           57        4025      67094     64  Assessment      6
# 11337823           59        3021      67094     64  Assessment      6
# 11337824           60        3121      67847     64  Assessment      6
# 11337825           61        2010      71511     64  Assessment      6
#
#                             title_event_code
# 1538            Welcome to Lost Lagoon!_2000
# 1539               Magma Peak - Level 1_2000
# 1540      Sandcastle Builder (Activity)_2000
# 1541      Sandcastle Builder (Activity)_3010
# 1542      Sandcastle Builder (Activity)_4070
# ...                                      ...
# 11337821   Cauldron Filler (Assessment)_2030
# 11337822   Cauldron Filler (Assessment)_4025
# 11337823   Cauldron Filler (Assessment)_3021
# 11337824   Cauldron Filler (Assessment)_3121
# 11337825   Cauldron Filler (Assessment)_2010
#
# [8294138 rows x 12 columns]

# %%
def get_train_and_test(train, test):
    compiled_train = []
    compiled_test = []
    for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
        #compiled_train += get_data(user_sample, test_set = False)
        train_data = get_data(user_sample, test_set = True)
        compiled_train.append(train_data)
    for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
        test_data = get_data(user_sample, test_set = True)
        compiled_test.append(test_data)
    reduce_train = pd.DataFrame(compiled_train)
    reduce_test = pd.DataFrame(compiled_test)
    categoricals = ['session_title']
    return reduce_train, reduce_test, categoricals

# %%
reduce_train, reduce_test, categoricals = get_train_and_test(train, test)
# Out:
#   0%|                                                                                        | 0/17000 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-198-fd300c5d3359> in <module>
# ----> 1 reduce_train, reduce_test, categoricals = get_train_and_test(train, test)
#
# <ipython-input-197-25a54056c6a9> in get_train_and_test(train, test)
#       4     for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
#       5         #compiled_train += get_data(user_sample, test_set = False)
# ----> 6         train_data = get_data(user_sample, test_set = True)
#       7         compiled_train.append(train_data)
#       8     for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
#
# NameError: name 'get_data' is not defined

# %% [markdown]
# # end lyons test

# %%
tr1 = train[train['installation_id'] == '0001e90f']

# %%
tr2 = tr1[tr1['event_code'] == 2000]

# %%
tr2
# Out:
#       event_id      game_session                        timestamp  \
# 0     27253bdc  45bb1e1b6b50c07b 2019-09-06 17:53:46.937000+00:00
# 1     27253bdc  17eeb7f223665f53 2019-09-06 17:54:17.519000+00:00
# 2     77261ab5  0848ef14a8dc6892 2019-09-06 17:54:56.302000+00:00
# 269   77261ab5  a1ec58f109218255 2019-09-06 17:58:28.042000+00:00
# 362   6d90d394  f11eb823348bfa23 2019-09-06 18:00:51.915000+00:00
# 1103  27253bdc  091587ed87b9637c 2019-09-06 18:10:51.183000+00:00
# 1104  51311d7a  07bacda7f9437b38 2019-09-06 18:11:28.381000+00:00
# 1246  77261ab5  ca8b415f34d12873 2019-09-06 18:16:25.132000+00:00
# 1355  27253bdc  3fce4f09769ff0b7 2019-09-06 18:18:11.250000+00:00
# 1356  27253bdc  04168b61c0650977 2019-09-06 18:18:42.392000+00:00
#
#                                              event_data installation_id  \
# 0                {"event_code": 2000, "event_count": 1}        0001e90f
# 1                {"event_code": 2000, "event_count": 1}        0001e90f
# 2     {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 269   {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 362   {"version":"1.0","level":0,"round":0,"event_co...        0001e90f
# 1103             {"event_code": 2000, "event_count": 1}        0001e90f
# 1104  {"version":"1.0","round":0,"event_count":1,"ga...        0001e90f
# 1246  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 1355             {"event_code": 2000, "event_count": 1}        0001e90f
# 1356             {"event_code": 2000, "event_count": 1}        0001e90f
#
#       event_count  event_code  game_time                          title  \
# 0               1        2000          0        Welcome to Lost Lagoon!
# 1               1        2000          0           Magma Peak - Level 1
# 2               1        2000          0  Sandcastle Builder (Activity)
# 269             1        2000          0  Sandcastle Builder (Activity)
# 362             1        2000          0                    Scrub-A-Dub
# 1103            1        2000          0           Magma Peak - Level 2
# 1104            1        2000          0                     Dino Drink
# 1246            1        2000          0  Sandcastle Builder (Activity)
# 1355            1        2000          0        Tree Top City - Level 1
# 1356            1        2000          0               Ordering Spheres
#
#           type        world
# 0         Clip         NONE
# 1         Clip    MAGMAPEAK
# 2     Activity    MAGMAPEAK
# 269   Activity    MAGMAPEAK
# 362       Game    MAGMAPEAK
# 1103      Clip    MAGMAPEAK
# 1104      Game    MAGMAPEAK
# 1246  Activity    MAGMAPEAK
# 1355      Clip  TREETOPCITY
# 1356      Clip  TREETOPCITY

# %%
st = specs[specs['event_id'] == '27253bdc']['info']

# %%
st.loc[343]
# Out:
# 'This event is triggered when a video starts playing'

# %%
sample.shape
# Out:
# (1000, 2)

# %%
train[train['installation_id'].isin(sample['installation_id'])].shape
# Out:
# (0, 11)

# %%
test[test['installation_id'].isin(sample['installation_id'])].shape
# Out:
# (1156414, 11)

# %%
test['installation_id'].nunique()
# Out:
# 1000

# %%
test['installation_id'].unique()
# Out:
# array(['00abaee7', '01242218', '017c5718', '01a44906', '01bc6cb6',
#        '02256298', '0267757a', '027e7ce5', '02a29f99', '0300c576',
#        '03885368', '03ac279b', '03e33699', '048e7427', '04a7bc3f',
#        '04d31500', '0500e23b', '0512bf0e', '0525589b', '05488e26',
#        '05771bba', '05b82cf5', '05e17e19', '0617500d', '068ae11f',
#        '0754f13b', '07749e99', '08611cc8', '08671ec7', '0889b0ae',
#        '090fe325', '0937340d', '09aaaf83', '09aefe80', '0a126293',
#        '0a2a77b2', '0a4c0f78', '0af94ba5', '0b24b6ac', '0b607c82',
#        '0d5735f2', '0d735146', '0d7752d3', '0dd670e9', '0de6863d',
#        '0e514571', '0e718764', '0ea27b66', '0f584054', '0f7116a6',
#        '101999d8', '101d16f5', '108044a0', '109ad724', '10acf963',
#        '1121f331', '1181ce7c', '11fa34d0', '125a3d09', '12771ee9',
#        '1294d68e', '12bcbbce', '13629687', '138a2ecc', '13a0754c',
#        '13bcaf23', '13cf3fc0', '13d608cb', '140087ce', '140ea7a3',
#        '1423dc8f', '14cdc97f', '153f087c', '1594c19e', '15d86999',
#        '15ec4544', '15f9b137', '16160dde', '1619f838', '16298f20',
#        '163ffbd7', '167fe32c', '16992352', '16f8159f', '17d1ea55',
#        '182fe06c', '18569185', '18a43ba3', '18dd112c', '1962067f',
#        '803ffba5', '80b51e23', '80c464d7', '80d2682f', '80d28878',
#        '80e0766c', '80f0f3d2', '81247ab3', '8127c0f7', '817fb400',
#        '819d08a4', '83cfc0b2', '8446fe1a', '844a6e20', '849ffc5e',
#        '84ad5637', '84ccdedf', '84fa3abb', '854dfe3a', '8551489a',
#        '85567705', '85a36690', '85d2f821', '869ec6d3', '86a08ba0',
#        '8712e11d', '876d9d93', '876e4c1c', '879f6a58', '87b899d9',
#        '87c15b6f', '87f58bfa', '88514bde', '8854354f', '886cebc2',
#        '88b74185', '88f5c349', '891c55ba', '893772d5', '89905528',
#        '89a1d680', '89bda256', '8a3aca1f', '8ace5f29', '8ae49f4c',
#        '8aed5ab4', '8b008e24', '8b29ddb4', '8b6dfb4c', '8b7b3eaa',
#        '8be4aedf', '8c16d72a', '8c539e8e', '8c7d8d9b', '8c9314db',
#        '8c9859b9', '8cd5bc7c', '8d03d0a5', '8d517034', '8d8f5d9f',
#        '8dc53df3', '8ddb7ac1', '8e333109', '8eab953e', '8eeba692',
#        '8f38fe78', '8f4e22b2', '8f71efea', '8fdb5402', '8fe03c35',
#        '9032b145', '9046e327', '904abba7', '9069db29', '90859667',
#        '909407b8', '90c8034d', '9131d5cf', '915c809a', '91796a02',
#        '91d4699e', '92468e29', '92d63f0f', '92e5a83a', '9323c154',
#        '933308f9', '93938a28', '940d51f8', '94a7461d', '94d43b7a',
#        '953ddba9', '957219b8', '959c3da3', '95b591c1', '95dfe687',
#        '95e63c0a', '96182fa7', '962183dc', '9638675f', '965c5adb',
#        '96a7f636', '96f57ec6', '9701ffb5', '972c2d7f', '97501794',
#        '97f14e50', '982cab25', '987a7222', '9885ddd8', '98c958c6',
#        '996a3149', '99e2b46c', '9a13c8a2', '9a5f6d12', '9a7f22db',
#        '9aa5dcea', '9aba2ff5', '9ae73003', '9afdf962', '9b001268',
#        '9b9eb930', '9bb426a7', '9bf6cb31', '9c20c73b', '9c217eb9',
#        '9c4cf176', '9c791ccc', '9ce70bef', '9cee9fc9', '9cfde2cc',
#        '9d43d142', '9d7e8158', '9dc9534c', '9e0880ca', '9e266d34',
#        '9e7e6cd8', '9e9f5e38', '9ea5577f', '9ec31362', '9f2a8f08',
#        '9f4b32f8', '9f688c66', '9f9119f4', '9fbe5106', 'a002f1ac',
#        'a07f6fc5', 'a0808b82', 'a0cc50c3', 'a11fe7b5', 'a1491477',
#        'a20e6921', 'a21c8e70', 'a22c1a5c', 'a23567d2', 'a2b6a4b8',
#        'a344c900', 'a3a93b63', 'a41a15f2', 'a447f081', 'a4856de5',
#        'a49120c7', 'a53d1ba0', 'a5ac9b55', 'a5ba72f9', 'a5ca7ea0',
#        'a6742227', 'a6f65253', 'a702d1c5', 'a71b99a6', 'a723a382',
#        'a788da19', 'a83e60be', 'a8668fb6', 'a87db7ff', 'a9190917',
#        'a93d6f19', 'a9566517', 'aa3dfd63', 'aa58cb91', 'aa84d895',
#        'aab22722', 'aac5d998', 'aadc1247', 'aaf695d0', 'ab83ea80',
#        'abc7eeda', 'ac44ef65', 'ac564de9', 'ad0f90e1', 'ad3c8e7b',
#        'add06668', 'ae10e514', 'aee093c4', 'af07fb5c', 'af08cb8d',
#        'af147c52', 'af1c1bee', 'af4572f6', 'af47aac5', 'af70bd34',
#        'af82ea2d', 'af83bf7c', 'af908793', 'afb1f807', 'aff5e5ee',
#        'b024bf05', 'b04d8f0c', 'b0efc6f4', 'b1bb8dd0', 'b1ce5ee9',
#        'b20c5326', 'b2235d5f', 'b23db0ea', 'b265d311', 'b2e2ed7d',
#        'b2e61027', 'b2f94d1f', 'b3451ce1', 'b3523d81', 'b3de6c53',
#        'b43665c9', 'b4738558', 'b479a4e5', 'b47d249b', 'b4a52ce8',
#        'b4ea7a14', 'b50add36', 'b51ba618', 'b55b1bec', 'b563ef9d',
#        'b5bb257a', 'b5be8f08', 'b5e21f0b', 'b68a3662', 'b6a4854f',
#        'b6b80f42', 'b6c3e1ab', 'b7adc30a', 'b7ce52b8', 'b7ffd685',
#        'b84e696a', 'b8ae746c', 'b8b6e81e', 'b905f26e', 'b98668f4',
#        'ba59e168', 'ba67bd3d', 'ba709e6a', 'ba91cc7f', 'bb6a19af',
#        'bbd98f65', 'bc1b756f', 'bc696a1e', 'bc81d58f', 'bca32990',
#        'bcc553ab', 'bccf5379', 'bd2e184f', 'bd337a90', 'bd4ed818',
#        'bd544e63', 'be0381e4', 'be1333d2', 'bec5a6ab', 'becd49ac',
#        'bed8b41c', 'bf287639', 'bf685281', 'bf6e55c3', 'bfddcc77',
#        'bfe1e41f', 'c1143024', 'c1406fca', 'c1617227', 'c195e65e',
#        'c1d8cab1', 'c233f4f4', 'c285f89d', 'c2a5380a', 'c2cfee57',
#        'c31c4183', 'c3cabf93', 'c4271e38', 'c42aeee6', 'c44551c7',
#        'c4957cd6', 'c4d15da1', 'c5609e08', 'c571fbe4', 'c59ae92a',
#        'c64ad87e', 'c664f245', 'c683651f', 'c6dcee3d', 'c6dd3ee6',
#        'c796f42b', 'c798859f', 'c83a956e', 'c85bfc99', 'c9057808',
#        'c92e8b4c', 'c9422f9c', 'c96f2dd1', 'c98f2490', 'c9ce5a9e',
#        'ca5f2610', 'ca61bf3a', 'cab2ca4a', 'cbf3a6f3', 'cc0963c8',
#        'cc7d27b2', 'cc8dd5f8', 'ccad11ca', 'ccb21848', 'cd00d04e',
#        'cd0e657d', 'cd2f3fbe', 'cd389d57', 'cda0fd9b', 'cdda168a',
#        'ce08e98b', 'cec7185c', 'cf22f7b2', 'cf434979', 'cfa3af82',
#        'cfd27471', 'd02d21ec', 'd096c7f6', 'd09b7e2e', 'd09cff3b',
#        'd09ebf52', 'd0ca8163', 'd192a327', 'd1ac59d7', 'd1b7c089',
#        'd1e3bd8c', 'd1e82789', 'd277cc27', 'd3167e9d', 'd32ee860',
#        'd33c3eeb', 'd373ded5', 'd3d56480', 'd3e70da6', 'd40a6175',
#        'd4201b5c', 'd473029e', 'd4b8e447', 'd4cc2b9f', 'd4d67a36',
#        'd4f34b24', 'd51199b6', 'd5a527da', 'd5c40330', 'd5d620e2',
te1[te1['type'] == 'Assessment'].shape
# Out:
# (1, 11)

# %%
te1
# Out:
#       event_id      game_session                 timestamp  \
# 3587  27253bdc  d1706431c69d0f17  2019-08-02T23:24:03.145Z
# 3588  27253bdc  7f8e671b050cfc16  2019-09-21T11:23:14.319Z
# 3589  27253bdc  9cbc7871cb68348e  2019-09-21T11:23:49.822Z
# 3590  27253bdc  dbe0b9903177b7ab  2019-09-21T11:24:14.904Z
# 3591  27253bdc  bada8e54f3bb8b3e  2019-09-21T11:24:34.545Z
# ...        ...               ...                       ...
# 3732  fcfdffb6  bb342a8258a1cd81  2019-09-21T11:28:02.171Z
# 3733  5d042115  bb342a8258a1cd81  2019-09-21T11:28:02.230Z
# 3734  fcfdffb6  bb342a8258a1cd81  2019-09-21T11:28:02.407Z
# 3735  a44b10dc  bb342a8258a1cd81  2019-09-21T11:28:02.516Z
# 3736  3bfd1a65  4b165a330a0bdd6c  2019-09-21T11:28:21.757Z
#
#                                              event_data installation_id  \
# 3587             {"event_code": 2000, "event_count": 1}        017c5718
# 3588             {"event_code": 2000, "event_count": 1}        017c5718
# 3589             {"event_code": 2000, "event_count": 1}        017c5718
# 3590             {"event_code": 2000, "event_count": 1}        017c5718
# 3591             {"event_code": 2000, "event_count": 1}        017c5718
# ...                                                 ...             ...
# 3732  {"flower":4,"flowers":[0,0,1,0,5],"coordinates...        017c5718
# 3733  {"flowers":[0,0,0,3,5],"flower":5,"coordinates...        017c5718
# 3734  {"flower":5,"flowers":[0,0,0,1,0],"coordinates...        017c5718
# 3735  {"coordinates":{"x":804,"y":358,"stage_width":...        017c5718
# 3736  {"version":"1.0","event_count":1,"game_time":0...        017c5718
#
#       event_count  event_code  game_time                         title  \
# 3587            1        2000          0       Welcome to Lost Lagoon!
# 3588            1        2000          0       Welcome to Lost Lagoon!
# 3589            1        2000          0       Welcome to Lost Lagoon!
# 3590            1        2000          0       Welcome to Lost Lagoon!
# 3591            1        2000          0       Tree Top City - Level 1
# ...           ...         ...        ...                           ...
# 3732           68        4022      51573     Flower Waterer (Activity)
# 3733           69        4030      51623     Flower Waterer (Activity)
# 3734           70        4022      51807     Flower Waterer (Activity)
# 3735           71        4070      51907     Flower Waterer (Activity)
# 3736            1        2000          0  Mushroom Sorter (Assessment)
#
#             type        world
# 3587        Clip         NONE
# 3588        Clip         NONE
# 3589        Clip         NONE
# 3590        Clip         NONE
# 3591        Clip  TREETOPCITY
# ...          ...          ...
# 3732    Activity  TREETOPCITY
# 3733    Activity  TREETOPCITY
# 3734    Activity  TREETOPCITY
# 3735    Activity  TREETOPCITY
# 3736  Assessment  TREETOPCITY
#
# [150 rows x 11 columns]

# %%
te1[te1['event_code'] == 2000].shape
# Out:
# (9, 11)

# %%
sample[sample['installation_id'] == 'ecaab346']
# Out:
# Empty DataFrame
# Columns: [installation_id, accuracy_group]
# Index: []

# %%
specs[specs['event_id'] == 'b74258a0']['info'].iloc[0]
# Out:
# 'The beat round event is triggered when the player finishes a round by successfully balancing the carts and submitting the solution. This event is used for calculating time spent in a round (for speed and accuracy), attempts at solving a round, and the number of rounds the player has completed (completion).'
